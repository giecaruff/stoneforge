# %%
# Loading Library
from stoneforge.data_management.preprocessing import DataLoader
from stoneforge.vis.img import fastplot

# %%
data,units = las_import(r"C:\Users\mario\Documents\appy_projetos\dados\7-MP-22-BA.las")

las2 = DataLoader(r"https://raw.githubusercontent.com/giecaruff/datasets/refs/heads/main/wells/las2/npra/DP1.las", filetype='las2')
print('header itens:',las2.data_obj.header.keys())
las2.data_obj.header['well']
data

# %%
curves = ["CALI","GR","RHOB","NPHI","Lith_new"]
units2 = []
for c in curves:
    units2.append(units[c])

color = ["k","g","r","b","navy"]

fastplot(data,"DEPTH",curves, color, units2)

# %%
colors ={
    25:"grey",
    49:"yellow",
    57:"green",
    54:"maroon",
    0:"black"
}

plt.subplot(1, 3, 1)
plt.plot(data["GR"],data["DEPTH"])
plt.grid()

plt.subplot(1, 3, 2)
plito(data["Lith_new"],data["DEPTH"],colors)
plt.grid()

# %%
LITO = {49,57,25,32}

print(type(LITO))
if 99 in LITO:
    print("is")
else:
    print('not')
