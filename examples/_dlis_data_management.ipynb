# %%
# %matplotlib widget
from stoneforge.io.dlisio_r import DLISAccess

dlis_manager = DLISAccess("../stoneforge/datasets/DSDP_leg_96_hole_616_96_processed_data.dlis", gui=False)
a = dlis_manager.select_header(idx=(0, 8, 3, 9, 19, 23, 26)) #idx=[0, 8, 3, 9, 19, 23, 26]
a
# Out:
#          Digital File Frame Name Mnemonics   Unit Dimension        Min  \
# 0     FDC/CNL/GR_main     B59067      TDEP      m        1D  -4.419456
# 3     FDC/CNL/GR_main     B59067      RHOB  g/cm3        1D  -0.913086
# 8     FDC/CNL/GR_main     B59067        GR   gAPI        1D   3.285156
# 9     FDC/CNL/GR_main     B59067      CALI     in        1D   7.818652
# 19    FDC/CNL/GR_main     B59067      NPHI      %        1D  32.958984
# 23  FDC/CNL/GR_repeat     B59180      TDEP      m        1D  -6.857943
# 26  FDC/CNL/GR_repeat     B59180      RHOB  g/cm3        1D  -1.547852
#
#            Max                                          Long Name
# 0   372.465607                                               None
# 3     3.863281                                       Bulk Density
# 8   141.375000                                          Gamma Ray
# 9     7.935532                                            Caliper
# 19  145.703125  Thermal Neutron Porosity (original Ratio Metho...
# ...

# %%
dlis_manager.get_data()
# Out:
# {'FDC/CNL/GR_main': {'B59067': {'TDEP': {'unit': 'm',
#     'values': array([372.4656   , 372.3132   , 372.1608   , ...,  -4.1146564,
#             -4.2670565,  -4.4194565], shape=(2474,), dtype=float32)},
#    'RHOB': {'unit': 'g/cm3',
#     'values': array([2.0898438, 2.0898438, 2.0898438, ..., 1.1201172, 1.1132812,
#            1.109375 ], shape=(2474,), dtype=float32)},
#    'GR': {'unit': 'gAPI',
#     'values': array([133.25     , 133.25     , 133.25     , ...,   3.765625 ,
#              3.7519531,   3.7539062], shape=(2474,), dtype=float32)},
#    'CALI': {'unit': 'in',
#     'values': array([7.8555613, 7.8555613, 7.8555613, ..., 7.898622 , 7.9232283,
#            7.898622 ], shape=(2474,), dtype=float32)},
#    'NPHI': {'unit': '%',
#     'values': array([ 61.279297,  61.279297,  61.279297, ...,  96.728516, 106.640625,
#             99.31641 ], shape=(2474,), dtype=float32)}}},
#  'FDC/CNL/GR_repeat': {'B59180': {'TDEP': {'unit': 'm',
# ...

# %%
dlis_manager.export(r"C:\Users\mario\Documents\test")
