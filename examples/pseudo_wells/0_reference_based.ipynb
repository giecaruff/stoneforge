# %%
# Importing necessary libraries

from stoneforge.pseudo_wells import anadrill_siliciclastic
from stoneforge.vis import wellplot, plito

import matplotlib.pyplot as plt
import pandas as pd

# %%
# Define facies and sampling structure
# For 'anadrill_siliciclastic' the facies are (in order):
# 0: shale; 1: clean_sandstone with gas; 2: clean_sandstone with oil; 3: clean_sandstone with brine; 4: feldspatic sandstone
# 5: unconsolidated sandstone with fresh water; 6: organic shale; 7: siltite; 8: dirty sandstone with brine

structure = {
    6: 400,   # Organic shale
    0: 400,   # Shale
    7: 400,   # Siltite
    3: 400,   # clean_sandstone with brine
}

well = anadrill_siliciclastic(structure, top = 1000.0, bottom = 2000.0, step=0.25, random_state=False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 13
#       1 # Define facies and sampling structure
#       2 # For 'anadrill_siliciclastic' the facies are (in order):
#       3 # 0: shale; 1: clean_sandstone with gas; 2: clean_sandstone with oil; 3: clean_sandstone with brine; 4: feldspatic sandstone
#       4 # 5: unconsolidated sandstone with fresh water; 6: organic shale; 7: siltite; 8: dirty sandstone with brine
#       6 structure = {
#       7     6: 400,   # Organic shale
#       8     0: 400,   # Shale
#       9     7: 400,   # Siltite
#      10     3: 400,   # clean_sandstone with brine
#      11 }
# ---> 13 well = anadrill_siliciclastic(structure, top = 1000.0, bottom = 2000.0, step=0.25, random_state=False)
#
# File ~\Documents\GitHub\stoneforge\stoneforge\pseudo_wells\referenced.py:37, in anadrill_siliciclastic(structure, step, top, bottom, random_state, noise)
#       8 def anadrill_siliciclastic(
#       9     structure: Annotated[dict, "Data structure"],
#      10     step: Annotated[float, "Depth step"]=1.0,
#    (...)     13     random_state: Annotated[bool, "Random state"]=False,
#      14     noise: Annotated[float, "Noise level"]=0.005):
#      16     """Generate synthetic well log data based on the SLB/Anadrill siliciclastic facies model adapted from :footcite:t:`slb1972,freire2020youtube`
#      17
#      18     Parameters
#    (...)     35         Dictionary containing synthetic well log data, with keys for each curve and facies.
#      36     """
# ---> 37     return (_generate(
#      38         structure,
#      39         data_path='anadrill_siliciclastic.ggf',
#      40         step=step,
#      41         top=top,
#      42         bottom=bottom,
#      43         random_state=random_state,
#      44         noise=noise
#      45     ),{'DEPTH':'m','GR':'API','RES':'ohm.m','NPHI':'m3/m3','DEN':'g/cm3','DT':'us/ft','INDEX':'','CODE':'','ROCK':'','FLUID':''})
#
# File ~\Documents\GitHub\stoneforge\stoneforge\pseudo_wells\referenced.py:100, in _generate(structure, data_path, step, top, bottom, random_state, noise)
#      97 sample_facies = next(iter(structure))
#      99 for k in example:
# --> 100     if isinstance(example[k][sample_facies], float):
#     101         header_f.append(k)
#     102     else:
#
# IndexError: tuple index out of range

# %%
well.keys()
# Out:
# dict_keys(['DEPTH', 'GR', 'RES', 'NPHI', 'DEN', 'DT', 'INDEX', 'CODE', 'ROCK', 'FLUID'])

# %%
data = pd.DataFrame.from_dict(well)
data
# Out:
#              DEPTH          GR        RES      NPHI       DEN          DT  \
# 0      1000.000000  127.456647  31.445738  0.334660  2.408478  113.481781
# 1      1000.082994  127.456647  31.445738  0.334660  2.408478  113.481781
# 2      1000.165989  127.456647  31.445738  0.334660  2.408478  113.481781
# 3      1000.248983  127.456647  31.445738  0.334660  2.408478  113.481781
# 4      1000.331978  127.456647  31.445738  0.334660  2.408478  113.481781
# ...            ...         ...        ...       ...       ...         ...
# 12045  1999.668022   24.566474   0.903932  0.133107  2.734104   67.935223
# 12046  1999.751017   24.566474   0.903932  0.133107  2.734104   67.935223
# 12047  1999.834011   24.566474   0.903932  0.133107  2.734104   67.935223
# 12048  1999.917006   24.566474   0.903932  0.133107  2.734104   67.935223
# 12049  2000.000000   24.566474   0.903932  0.133107  2.734104   67.935223
#
#        INDEX  CODE             ROCK  FLUID
# 0          6    54    organic_shale   none
# 1          6    54    organic_shale   none
# 2          6    54    organic_shale   none
# 3          6    54    organic_shale   none
# 4          6    54    organic_shale   none
# ...      ...   ...              ...    ...
# 12045      3    27  clean_sandstone  brine
# 12046      3    27  clean_sandstone  brine
# 12047      3    27  clean_sandstone  brine
# 12048      3    27  clean_sandstone  brine
# 12049      3    27  clean_sandstone  brine
#
# [12050 rows x 10 columns]

# %%
units
# Out:
# {'DEPTH': 'm',
#  'GR': 'API',
#  'RES': 'ohm.m',
#  'NPHI': 'm3/m3',
#  'DEN': 'g/cm3',
#  'DT': 'us/ft',
#  'INDEX': '',
#  'CODE': '',
#  'ROCK': '',
#  'FLUID': ''}

# %%
curves = ['GR','NPHI', 'DEN', 'DT']
units2 = []
for c in curves:
    units2.append(units[c])

color = ["green","navy","red","magenta"]

wellplot(data,"DEPTH",curves, color, units2)

# %%
colors ={
    27:"darkgreen",
    25:"grey",
    49:"yellow",
    57:"green",
    54:"maroon",
    0:"black"
}

plt.subplot(1, 3, 1)
plt.plot(data["GR"],data["DEPTH"],color="green")
plt.grid()

plt.subplot(1, 3, 2)
plt.plot(data["NPHI"],data["DEPTH"],color="navy")
plt.grid()

plt.subplot(1, 3, 3)
plito(data["CODE"],data["DEPTH"],colors)
plt.grid()

# %%
set(data["CODE"])
# Out:
# {25, 27, 49, 54}
