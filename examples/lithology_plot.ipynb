# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from stoneforge.petrophysics import shale_volume, porosity, water_saturation
from stoneforge.datasets import dataload
from stoneforge.preprocessing import las_import
from stoneforge.vis import wellplot, plito

# %%
data,units = las_import(r"C:\Users\mario\Documents\appy_projetos\dados\7-MP-22-BA.las")
data
# Out:
#           DEPTH  BS  CALI  GR  HDRS    RHOB    NPHI  DT    DRDN  Lith_new
# 0         9.925 NaN   NaN NaN   NaN     NaN     NaN NaN     NaN       NaN
# 1        10.025 NaN   NaN NaN   NaN     NaN     NaN NaN     NaN       NaN
# 2        10.125 NaN   NaN NaN   NaN     NaN     NaN NaN     NaN       NaN
# 3        10.225 NaN   NaN NaN   NaN     NaN     NaN NaN     NaN       NaN
# 4        10.325 NaN   NaN NaN   NaN     NaN     NaN NaN     NaN       NaN
# ...         ...  ..   ...  ..   ...     ...     ...  ..     ...       ...
# 30767  3086.625 NaN   NaN NaN   NaN  2.5585  0.0711 NaN -1.4591      49.0
# 30768  3086.725 NaN   NaN NaN   NaN  2.5585  0.0711 NaN -1.4591      49.0
# 30769  3086.825 NaN   NaN NaN   NaN  2.5585  0.0711 NaN -1.4591      49.0
# 30770  3086.925 NaN   NaN NaN   NaN  2.5585  0.0711 NaN -1.4591      49.0
# 30771  3087.025 NaN   NaN NaN   NaN  2.5585  0.0711 NaN -1.4591      49.0
#
# [30772 rows x 10 columns]

# %%
curves = ["CALI","GR","RHOB","NPHI","Lith_new"]
units2 = []
for c in curves:
    units2.append(units[c])

color = ["k","g","r","b","navy"]

wellplot(data,"DEPTH",curves, color, units2)

# %%
colors ={
    25:"grey",
    49:"yellow",
    57:"green",
    54:"maroon",
    0:"black"
}

plt.subplot(1, 3, 1)
plt.plot(data["GR"],data["DEPTH"])
plt.grid()

plt.subplot(1, 3, 2)
plito(data["Lith_new"],data["DEPTH"],colors)
plt.grid()

# %%
LITO = {49,57,25,32}

print(type(LITO))
if 99 in LITO:
    print("is")
else:
    print('not')
# Out:
# <class 'set'>
# not
