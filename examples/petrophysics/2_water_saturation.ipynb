# %%
# Importing necessary libraries

from stoneforge.petrophysics.water_saturation import archie, simandoux, indonesia, fertl
from stoneforge.petrophysics.shale_volume import vshale_larionov_old
from stoneforge.petrophysics.porosity import density_porosity
from stoneforge.data_management.preprocessing import DataLoader
from stoneforge.vis.img import fastplot

import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
# Accessing Internal Dataframe for MP_56D Well

DATA = DataLoader(r"https://raw.githubusercontent.com/giecaruff/datasets/refs/heads/main/wells/las2/massape/7-MP-56D-BA.las", filetype='las2')
data_MP_56D, units_MP_56D = DATA.dataframe(DATA.data_obj.data)
data_MP_56D
# Out:
#            DEPTH   BS       GR    CALI       DT     RT30     RT60     RT90  \
# 0      1868.0001  8.5  96.0140  9.6470  91.3812   2.4726   2.4300   2.4973
# 1      1868.1001  8.5  96.2027  9.5881  91.0722   2.4536   2.4127   2.4801
# 2      1868.2001  8.5  97.7789  9.5809  90.1369   2.4079   2.3687   2.4348
# 3      1868.3001  8.5  98.0069  9.5892  89.3943   2.3368   2.3003   2.3639
# 4      1868.4001  8.5  98.5336  9.4958  89.6868   2.1647   2.1346   2.1917
# ...          ...  ...      ...     ...      ...      ...      ...      ...
# 13045  3172.5001  8.5  87.5305  7.2086  66.0265  12.3590  12.2146  12.0041
# 13046  3172.6001  8.5  88.2076  7.2082  65.5312  12.3572  12.1929  11.9750
# 13047  3172.7001  8.5  89.5980  7.2113  65.9171  12.3821  12.1954  11.9688
# 13048  3172.8001  8.5  91.4339  7.2124  66.3742  12.7422  12.4908  12.2348
# 13049  3172.9001  8.5      NaN  7.2118  66.8357  13.0314  12.7365  12.4612
#
#          RHOB    DRHO    NPHI
# 0         NaN     NaN     NaN
# ...

# %%
# Accessing Internal Dataframe units for MP_56D Well

print(units_MP_56D)
# Out:
# {'DEPTH': 'M', 'BS': 'in', 'GR': 'gapi', 'CALI': 'in', 'DT': 'uspf', 'RT30': 'ohmm', 'RT60': 'ohmm', 'RT90': 'ohmm', 'RHOB': 'g/cc', 'DRHO': 'g/cc', 'NPHI': 'decp'}

# %%
# Viewing Well Log Data

curves = ["CALI","GR","RHOB","NPHI","DT"]
units = []
for c in curves:
    units.append(units_MP_56D[c])

color = ["k","g","r","b","navy"]

fastplot(data_MP_56D,"DEPTH",curves, color, units, d_unit='m')

# %%
# Removing specific values
# OBS: you can use "df.dropna(inplace=True)" to remove all np.nan values

data_MP_56D_c = data_MP_56D[~data_MP_56D.isin([-999.0]).any(axis=1)]
data_MP_56D_c
# Out:
#            DEPTH   BS       GR    CALI       DT     RT30     RT60     RT90  \
# 0      1868.0001  8.5  96.0140  9.6470  91.3812   2.4726   2.4300   2.4973
# 1      1868.1001  8.5  96.2027  9.5881  91.0722   2.4536   2.4127   2.4801
# 2      1868.2001  8.5  97.7789  9.5809  90.1369   2.4079   2.3687   2.4348
# 3      1868.3001  8.5  98.0069  9.5892  89.3943   2.3368   2.3003   2.3639
# 4      1868.4001  8.5  98.5336  9.4958  89.6868   2.1647   2.1346   2.1917
# ...          ...  ...      ...     ...      ...      ...      ...      ...
# 13045  3172.5001  8.5  87.5305  7.2086  66.0265  12.3590  12.2146  12.0041
# 13046  3172.6001  8.5  88.2076  7.2082  65.5312  12.3572  12.1929  11.9750
# 13047  3172.7001  8.5  89.5980  7.2113  65.9171  12.3821  12.1954  11.9688
# 13048  3172.8001  8.5  91.4339  7.2124  66.3742  12.7422  12.4908  12.2348
# 13049  3172.9001  8.5      NaN  7.2118  66.8357  13.0314  12.7365  12.4612
#
#          RHOB    DRHO    NPHI
# 0         NaN     NaN     NaN
# ...

# %%
# Viewing Cleaned Well Log Data

fastplot(data_MP_56D_c,"DEPTH",curves, color, units, d_unit='m')

# %%
# Taking specific range in depth for analysis (reservoir interval)

RESERVOIR = data_MP_56D_c[data_MP_56D_c['DEPTH'].between(2800, 3200)]
fastplot(RESERVOIR,"DEPTH",curves, color, units, d_unit='m')

# %%
# VSH Calculations

GR = np.array(RESERVOIR["GR"])

GR_min = 50
GR_max = 100
print("GR_min:",GR_min,"|GR_max:",GR_max)

VSH = vshale_larionov_old(gr=GR,grmin=GR_min,grmax=GR_max)
# Out:
# GR_min: 50 |GR_max: 100

# %%
# PHI Calculations

NPHI = np.array(RESERVOIR["NPHI"])
RHOB = np.array(RESERVOIR["RHOB"])

PHID = density_porosity(rhob=RHOB)

# %%
# SW Calculations

ILD = np.array(RESERVOIR["RT90"])

SW = {
    "DEPTH":RESERVOIR["DEPTH"],
    "archie": archie(rt=ILD,phi=PHID),
    "simandoux": simandoux(rt=ILD,phi=PHID,vsh=VSH),
    "indonesia": indonesia(rt=ILD,phi=PHID,vsh=VSH),
    "fertl": fertl(rt=ILD,phi=PHID,vsh=VSH)
}

RESERVOIR_SW = pd.DataFrame(SW)

# %%
# Plotting SW results

curves = ["archie","simandoux","indonesia","fertl"]
units = ["","","",""]
color = ["teal","teal","teal","teal"]

fastplot(RESERVOIR_SW,"DEPTH",curves, color, units, d_unit='ft')
