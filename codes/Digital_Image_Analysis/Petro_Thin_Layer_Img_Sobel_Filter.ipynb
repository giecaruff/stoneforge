# %%
from Sobel import sobel
from PIL import Image
from numpy import asarray
import numpy as np
from skimage import io, color
from skimage.io import imread
import matplotlib.pyplot as plt


lina_color = io.imread('Lamina_1.jpg')
lina_gray = color.rgb2gray(lina_color)

# %%
input_img = lina_gray.astype(np.float32)

# %%
sobel_img = sobel(input_img)

# %%
sobel_img
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 1.2589191 , 1.2665606 , ..., 1.1322329 , 1.2912308 ,
#         0.        ],
#        [0.        , 1.289604  , 0.41994682, ..., 0.34088972, 1.1843405 ,
#         0.        ],
#        ...,
#        [0.        , 1.0452827 , 0.5889553 , ..., 0.26417685, 0.7292195 ,
#         0.        ],
#        [0.        , 1.0248272 , 1.0638332 , ..., 0.759515  , 0.82513887,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ]], dtype=float32)

# %%
plt.imshow(input_img,cmap='gray',aspect="equal")

# %%
plt.imshow(sobel_img,cmap='gray',aspect="equal")
