# %%
import stoneforge

# %%
from stoneforge.datasets import alaska_usgs

# %%
b = stoneforge.petrophysics.porosity.effective_porosity()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 b = stoneforge.petrophysics.porosity.effective_porosity()
#
# TypeError: effective_porosity() missing 2 required positional arguments: 'phi' and 'vsh'

# %%
a = alaska_usgs
print(a)
# Out:
# <module 'stoneforge.datasets.alaska_usgs' (namespace)>
